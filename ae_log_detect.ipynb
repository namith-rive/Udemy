# %% [markdown]
# <a href="https://colab.research.google.com/github/namith-rive/Udemy/blob/main/ae_log_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ae_log_train.py

# %%
# -*- coding: utf-8 -*-
# 実行方法　python3 this.py datafile

import os
import sys
import numpy as np
import pandas as pd
import keras.models
from keras.layers import Dense, BatchNormalization, Activation
from keras.models import Sequential

#ModelFile = "./ae_log_model.h5"
#ModelFile = '/content/drive/MyDrive/ae_image_model.h5'
ModelFile = '/content/drive/MyDrive/ae_log_model.h5'

# 入力データの項目数
INPUT_SIZE = 16

# 学習用データの読み込み
#Datafolder = '/content/drive/MyDrive/image_train'　（画像の場合）
Datafile = '/content/drive/MyDrive/data_log_train.csv'

train_data = pd.read_csv(Datafile)

# AutoEncoderモデルの組み立て
model = Sequential()
model.add(Dense(INPUT_SIZE,input_shape=(INPUT_SIZE,)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(int(INPUT_SIZE/2)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(INPUT_SIZE))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(INPUT_SIZE))
model.compile(optimizer='adam',
                       loss='mean_squared_error')
model.summary()

# 学習：入力データと結果データを同一にする
history = model.fit(x=train_data, y=train_data,
                             epochs=100,
                             batch_size=4,
                             validation_split=0.1)

# 学習済みモデルを保存
model.save(ModelFile)
print('Model saved.')
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 16)                272
#
#  batch_normalization_3 (Bat  (None, 16)                64
#  chNormalization)
#
#  activation_3 (Activation)   (None, 16)                0
#
#  dense_5 (Dense)             (None, 8)                 136
#
#  batch_normalization_4 (Bat  (None, 8)                 32
#  chNormalization)
#
#  activation_4 (Activation)   (None, 8)                 0
#
#  dense_6 (Dense)             (None, 16)                144
#
#  batch_normalization_5 (Bat  (None, 16)                64
#  chNormalization)
#
#  activation_5 (Activation)   (None, 16)                0
#
#  dense_7 (Dense)             (None, 16)                272
#
# ...
# Total params: 984 (3.84 KB)
# Trainable params: 904 (3.53 KB)
# Non-trainable params: 80 (320.00 Byte)
# ...

# %% [markdown]
# ### ae_log_detect.py

# %%
# -*- coding: utf-8 -*-
# 実行方法　python3 this.py datafile

import os
import sys
import numpy as np
import pandas as pd
import keras.models
from sklearn.metrics import mean_squared_error

#ModelFile = "./ae_log_model.h5"
ModelFile = '/content/drive/MyDrive/ae_log_model.h5'

if not os.path.exists(ModelFile):
    print("Modelfile not exist.")
    exit()

Datafile = '/content/drive/MyDrive/data_log_detect1.csv'

model = keras.models.load_model(ModelFile)

# 検出用データを読み込んで誤差を計算
detect_data = pd.read_csv(Datafile, header=None)
detect_pred = model.predict(detect_data)
detect_score = mean_squared_error(detect_data, detect_pred)
print('Score: ', detect_score)
# Out:
# 1/1 [==============================] - 0s 193ms/step
# Score:  0.2760318950646621
